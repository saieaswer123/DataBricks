# %%
from pyspark.sql.functions import *

df=spark.read.table("`2_learning`.`2_learning_schema`.movies_1")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.count()
# Out:
# 37

# %%
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- industry: string (nullable = true)
#  |-- release_year: long (nullable = true)
#  |-- imdb_rating: string (nullable = true)
#  |-- studio: string (nullable = true)
#  |-- budget: double (nullable = true)
#  |-- revenue: double (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- language: string (nullable = true)

# %%
df_select=df.select('title','industry')
df_select.show(truncate=False) #By indication it false it shows full name of columns otherwise it shows only 20 characters
# Out:
# +-------------------------------------------+---------+
# |title                                      |industry |
# +-------------------------------------------+---------+
# |Pather Panchali                            |Bollywood|
# |Doctor Strange in the Multiverse of Madness|Hollywood|
# |Thor: The Dark World                       |Hollywood|
# |Thor: Ragnarok                             |Hollywood|
# |Thor: Love and Thunder                     |Hollywood|
# |The Shawshank Redemption                   |Hollywood|
# |Interstellar                               |Hollywood|
# |The Pursuit of Happyness                   |Hollywood|
# |Gladiator                                  |Hollywood|
# |Titanic                                    |Hollywood|
# |It's a Wonderful Life                      |Hollywood|
# |Avatar                                     |Hollywood|
# |The Godfather                              |Hollywood|
# |The Dark Knight                            |Hollywood|
# ...

# %%
df_select=df.select('title','industry')
df_select.show(truncate=True)
# Out:
# +--------------------+---------+
# |               title| industry|
# +--------------------+---------+
# |     Pather Panchali|Bollywood|
# |Doctor Strange in...|Hollywood|
# |Thor: The Dark Wo...|Hollywood|
# |     Thor: Ragnarok |Hollywood|
# |Thor: Love and Th...|Hollywood|
# |The Shawshank Red...|Hollywood|
# |        Interstellar|Hollywood|
# |The Pursuit of Ha...|Hollywood|
# |           Gladiator|Hollywood|
# |             Titanic|Hollywood|
# |It's a Wonderful ...|Hollywood|
# |              Avatar|Hollywood|
# |       The Godfather|Hollywood|
# |     The Dark Knight|Hollywood|
# |    Schindler's List|Hollywood|
# |       Jurassic Park|Hollywood|
# |            Parasite|Hollywood|
# |   Avengers: Endgame|Hollywood|
# |Avengers: Infinit...|Hollywood|
# |Captain America: ...|Hollywood|
# +--------------------+---------+
# only showing top 20 rows

# %%
df_select.show(6) #By meantioning number we can get those number of rows
# Out:
# +--------------------+---------+
# |               title| industry|
# +--------------------+---------+
# |     Pather Panchali|Bollywood|
# |Doctor Strange in...|Hollywood|
# |Thor: The Dark Wo...|Hollywood|
# |     Thor: Ragnarok |Hollywood|
# |Thor: Love and Th...|Hollywood|
# |The Shawshank Red...|Hollywood|
# +--------------------+---------+
# only showing top 6 rows

# %%
df.filter((df.release_year>=2000)&(df.release_year<=2010)).orderBy(df.release_year).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.filter(df.studio=="Marvel Studios").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.select(df.industry).distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>industry</th></tr></thead><tbody><tr><td>Bollywood</td></tr><tr><td>Hollywood</td></tr></tbody></table></div>

# %%
df.withColumn("Profit",df.revenue-df.budget).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.withColumnRenamed("revenue","Total_Revenue").display()  #This is for renaming column
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.csv("/Volumes/2_learning/2_learning_schema/day_2_volume/orders.csv",header=True,inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import *
df=df.withColumn("order_date",date_format(df.order_date,"dd-mm-yyyy"))
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
